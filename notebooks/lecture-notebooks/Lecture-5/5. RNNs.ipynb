# %%
# !pip install d2l==0.16.1

# %%
from d2l import torch as d2l
import torch

# %% [markdown]
# # Recurrent Neural Networks
#
# ## Hiddent States vs Hidden Layers
#
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
#
# ## Neural Networks without Hidden States
#
# ... recalling matrix operations
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
# ## Recurrent Neural Networks with Hidden States
#
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
X, W_xh = torch.normal(0, 1, (3, 1)), torch.normal(0, 1, (1, 4))
H, W_hh = torch.normal(0, 1, (3, 4)), torch.normal(0, 1, (4, 4))
torch.matmul(X, W_xh) + torch.matmul(H, W_hh)
# Out:
# tensor([[-2.2343,  1.2193, -2.9345, -0.8484],
#         [ 2.1895, -3.5368,  2.1036, -1.7839],
#         [-0.7506, -0.2706, -0.5786, -1.0822]])

# %% [markdown]
# Now we concatenate the matrices `X` and `H`
# along columns (axis 1),
# and the matrices
# `W_xh` and `W_hh` along rows (axis 0).
# These two concatenations
# result in
# matrices of shape (3, 5)
# and of shape (5, 4), respectively.
# Multiplying these two concatenated matrices,
# we obtain the same output matrix of shape (3, 4)
# as above.

# %%
torch.matmul(torch.cat((X, H), 1), torch.cat((W_xh, W_hh), 0))
# Out:
# tensor([[-2.2343,  1.2193, -2.9345, -0.8484],
#         [ 2.1895, -3.5368,  2.1036, -1.7839],
#         [-0.7506, -0.2706, -0.5786, -1.0822]])

# %% [markdown]
# ## RNN-based Character-Level Language Models
#
# <br>
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>
#
#
# ## Perplexity
#
#
# <br><br><br><br><br><br><br><br><br><br><br><br>
#
# $$\frac{1}{n} \sum_{t=1}^n -\log P(x_t \mid x_{t-1}, \ldots, x_1),$$
#
#
#
#
# <br><br><br><br><br><br>
#
# $$\exp\left(-\frac{1}{n} \sum_{t=1}^n \log P(x_t \mid x_{t-1}, \ldots, x_1)\right).$$
